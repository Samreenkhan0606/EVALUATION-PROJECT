# %% [markdown]
# <h2 style='text-align:center;font-size:80px;background-color:black;border:80px;color:white'>   Zomato Restaurant Project
#  . <h2>

# %% [markdown]
# # Problem Statement

# %% [markdown]
# ### Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the bestcuisines of every part of the world which lies in their budget. This analysis is also for those whowant to find the value for money restaurants in various parts of the country for the cuisines.

# %% [markdown]
# ### Additionally, this analysis caters the needs of people who are striving to get the best cuisine ofthe country and which locality of that country serves that cuisines with maximum number ofrestaurants.

# %% [markdown]
# ## This problem statement contains two datasets- `Zomato.csv` and `country_code.csv`.

# %% [markdown]
# ### Country_code.csv contains two variables:
# - Country code
# - Country name

# %% [markdown]
# #### The collected data has been stored in the Comma Separated Value file Zomato.csv

# %% [markdown]
# ### Each restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
#
# - • Restaurant Id: Unique id of every restaurant across various cities of the world
# - • Restaurant Name: Name of the restaurant
# - • Country Code: Country in which restaurant is located
# - • City: City in which restaurant is located
# - • Address: Address of the restaurant
# - • Locality: Location in the city
# - • Locality Verbose: Detailed description of the locality
# - • Longitude: Longitude coordinate of the restaurant&#39;s location
# - • Latitude: Latitude coordinate of the restaurant&#39;s location
# - • Cuisines: Cuisines offered by the restaurant
# - • Average Cost for two: Cost for two people in different currencies ��
# - • Currency: Currency of the country
# - • Has Table booking: yes/no
# - • Has Online delivery: yes/ no
# - • Is delivering: yes/ no
# - • Switch to order menu: yes/no
# - • Price range: range of price of food
# - • Aggregate Rating: Average rating out of 5
# - • Rating color: depending upon the average rating color
# - • Rating text: text on the basis of rating of rating
# - • Votes: Number of ratings casted by people

# %% [markdown]
# ### Problem statement : In this dataset predict 2 things –
# 1)` Average Cost for two`
#
# 2) `Price range`

# %% [markdown]
# # ====================================

# %%
##Lets import some Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the csv file from dataset
df = pd.read_csv("zomato.csv")
pd.set_option("display.max_columns",None)
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# #### In Dataset Zomato.csv there are 9551 rows and 21 columns

# %%
df1=pd.read_excel('Country-Code.xlsx')
df1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %% [markdown]
# #### In Dataset Country-Code.csv there are Country Code and Country

# %% [markdown]
# ### Now lets Merge the Both Dataset

# %%
df = pd.merge(df,df1,on='Country Code',how='left')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...     Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...    Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karak�_y, ��stanbul  28.977392  41.022793
# ...

# %%
df.sample(5)
# Out:
#       Restaurant ID                            Restaurant Name  Country Code  \
# 5860           2370                                       Dips             1
# 4200           7025                                   Suruchee             1
# 5352           8462                  New Aggarwal Sweet Corner             1
# 8670       18463984                                    Cafe 44             1
# 3254       18355127  Muradabadi Shahi Biryani & Chicken Corner             1
#
#            City                                            Address  \
# 5860  New Delhi  G 37, Aggarwal Millenium, Netaji Subhash Place...
# 4200  New Delhi  71/139, Prem Nagar, Near Choti Sabzi Mandi, Ja...
# 5352  New Delhi  A-1240/2, DDA Market, Mayur Vihar Phase 3, New...
# 8670      Noida                A15/11, 1st Floor, Sector 44, Noida
# 3254  New Delhi  A-181, Sukhdev Market, Kotla Mubarakpur, Defen...
#
#                   Locality                 Locality Verbose  Longitude  \
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# #### These are column names present in dataset

# %%
# Now lets identify which types of data types do they all belongs

df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %% [markdown]
# #### Dataset have int64,object and float64 as data type..Target variable Average Cost of two is int64 which make it a Regression problem

# %% [markdown]
# <h2 style='text-align:center;font-size:50px;background-color:white;border:50px;color:black'> EDA <h2>

# %%
# To get the information about the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# - Here we get the Information regarding Column,Non-Null Count(columns having NaN Values) ,Dtypes and Memory usage of the dataset ....
# - Here we can see that all the columns counts are equal except Cuisines which means that there is no Missing values except in one columns ..
# - There are three data type present in dataset float64,int64,object.. in which 3 columns zre of float64, 5 columns of int64 and 14 columns of object..

# %% [markdown]
# ## NOW LETS CHECK THE NULL VALUES

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# #### Cuisines have nan values

# %%
# Let's visualize NaN values
sns.heatmap(df.isnull(),cmap="Paired")
plt.show()

# %% [markdown]
# #### Count of nan is less so it is not visible in heatmap

# %%
missing = pd.DataFrame((df.isnull().sum())*100/df.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot('index',0,data=missing)
plt.xticks(rotation =90,fontsize =11)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %% [markdown]
# #### Hike at cuisine shows present of nan value in column

# %%
nan_values = df.isna()
nan_columns = nan_values.any()

columns_with_nan = df.columns[nan_columns].tolist()
print(columns_with_nan)
# Out:
# ['Cuisines']

# %%
print(df['Cuisines'].unique())
# Out:
# ['French, Japanese, Desserts' 'Japanese'
#  'Seafood, Asian, Filipino, Indian' ... 'Burger, Izgara'
#  'World Cuisine, Patisserie, Cafe' 'Italian, World Cuisine']

# %% [markdown]
# #### Here i am not filling nan with mode value becoz every country have there speciality which may be or may not be present in other countries.. so going to fill nan with no dishes..

# %%
df['Cuisines']=df['Cuisines'].fillna("No Cuisines")

# %%
len(df[df['Cuisines']=='No Cuisines'])
# Out:
# 9

# %%
#Lets plot gain to check if nan have removed or not
missing = pd.DataFrame((df.isnull().sum())*100/df.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot('index',0,data=missing)
plt.xticks(rotation =90,fontsize =11)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %% [markdown]
# #### Straight shows that nan values is not present in dataset which means nan values has been filled

# %%
# Value counts of each columns
for i in df.columns:
        print(df[i].value_counts())
        print('\n\n')
        print ('*'*100)
# Out:
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: Restaurant ID, Length: 9551, dtype: int64
#
#
#
# ****************************************************************************************************
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
#
#
#
# ****************************************************************************************************
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# ...

# %% [markdown]
# - Almost 10% data are 0 in Votes
# - Almost 20% data is 0 in Aggregate rating
# - We can see that maximum resturants are From India which is Somewhere around 50%
# - MAximum restaurants have a locality verbose of Connaught place
# - longitude and Latitude have  value as 0

# %%
# Checking which columns contains "?" sign as it is a NaN value
df[df.columns[(df == '?').any()]].nunique()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# #### Dataset dont have ? with we can see in value count also

# %%
# Dropping Address coloum from the dataset bcz it is not making any sense to know the exact address
df.drop("Address",axis=1,inplace=True)

# %%
# Checking number of unique values in each column
df.nunique().to_frame("No of Unique Values")
# Out:
#                       No of Unique Values
# Restaurant ID                        9551
# Restaurant Name                      7446
# Country Code                           15
# City                                  141
# Locality                             1208
# Locality Verbose                     1265
# Longitude                            8120
# Latitude                             8677
# Cuisines                             1826
# Average Cost for two                  140
# Currency                               12
# Has Table booking                       2
# Has Online delivery                     2
# Is delivering now                       2
# Switch to order menu                    1
# Price range                             4
# Aggregate rating                       33
# Rating color                            6
# Rating text                             6
# Votes                                1012
# Country                                15

# %% [markdown]
# #### These are the unique values present in each column.We can observe the columns Restaurant ID have 9551 unique values which means they have only one value count. So it not required for the prediction so we can drop it.

# %%
# Dropping Restaurant ID columns
df.drop("Restaurant ID",axis=1,inplace=True)

# %% [markdown]
# # Separating numerical and categorcal columns

# %%
# Checking for categorical columns
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_col.append(i)
print("Categorical columns are:\n",categorical_col)
# Out:
# Categorical columns are:
#  ['Restaurant Name', 'City', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Rating color', 'Rating text', 'Country']

# %%
# Now checking for numerical columns
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_col.append(i)
print("Numerical columns are:\n",numerical_col)
# Out:
# Numerical columns are:
#  ['Country Code', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %% [markdown]
# ## Lets Groupby 4 columns which relates to each other

# %%
df2 = df.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
df2
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# The above information helps us to understand the realation between Aggregate rating, color and text. We conclude the following color assigned to the ratings:
# Rating 0 - White - Not rated
#
# Rating 1.8 to 2.4 - Red - Poor
#
# *Rating 2.5 to 3.4 - Orange - Average
#
# Rating 3.5 to 3.9 - Yellow - Good
#
# Rating 4.0 to 4.4 - Green - Very Good
#
# Rating 4.5 to 4.9 - Dark Green - Excellent

# %%
# Checking the list of counts of Aggregate Rating
df['Aggregate rating'].unique()
# Out:
# array([4.8, 4.5, 4.4, 4.9, 4. , 4.2, 4.3, 3.6, 4.7, 3. , 3.8, 3.7, 3.2,
#        3.1, 0. , 4.1, 3.3, 4.6, 3.9, 3.4, 3.5, 2.2, 2.9, 2.4, 2.6, 2.8,
#        2.1, 2.7, 2.5, 1.8, 2. , 2.3, 1.9])

# %%
df['Aggregate rating'].value_counts()
# Out:
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %%
# Checking wheather the target vaiable contains any space
df.loc[df['Average Cost for two']==" "]
# Out:
# Empty DataFrame
# Columns: [Restaurant Name, Country Code, City, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes, Country]
# Index: []

# %% [markdown]
# #### Target variable does not contains any space

# %%
No_rating = df[df['Rating color']=='White'].groupby('Country').size().reset_index().rename(columns={0:'Rating Count'})
No_rating
# Out:
#           Country  Rating Count
# 0          Brazil             5
# 1           India          2139
# 2  United Kingdom             1
# 3   United States             3

# %% [markdown]
# #### India seems to have maximum unrated restaurants. In India the culture of ordering online food is still gaining momentum hence most of the restaurants are still unrated on Zomato as people might be preferring to visiting the restaurant for a meal.

# %%
Max_rating = df[df['Rating color']=='Dark Green'].groupby('Country').size().reset_index().rename(columns={0:'Rating Count'})
Max_rating
# Out:
#            Country  Rating Count
# 0        Australia             1
# 1           Brazil            16
# 2            India           116
# 3        Indonesia             7
# 4      New Zealand            12
# 5      Phillipines            12
# 6            Qatar             4
# 7     South Africa            12
# 8        Sri Lanka             2
# 9           Turkey            10
# 10             UAE            18
# 11  United Kingdom            23
# 12   United States            68

# %% [markdown]
# #### Max rating restuarants are also found in India .. This may be because India has the maximum restuarants listed on Zomato from all over the world

# %%
country_currency = df[['Country','Currency']].groupby(['Country','Currency']).size().reset_index(name='count').drop('count', axis=1, inplace=False)
country_currency.sort_values('Currency').reset_index(drop=True)
# Out:
#            Country                Currency
# 0      Phillipines        Botswana Pula(P)
# 1           Brazil      Brazilian Real(R$)
# 2        Australia               Dollar($)
# 3           Canada               Dollar($)
# 4        Singapore               Dollar($)
# 5    United States               Dollar($)
# 6              UAE      Emirati Diram(AED)
# 7            India      Indian Rupees(Rs.)
# 8        Indonesia  Indonesian Rupiah(IDR)
# 9      New Zealand           NewZealand($)
# 10  United Kingdom              Pounds(��)
# 11           Qatar         Qatari Rial(QR)
# 12    South Africa                 Rand(R)
# 13       Sri Lanka   Sri Lankan Rupee(LKR)
# 14          Turkey        Turkish Lira(TL)

# %% [markdown]
# #### I have done groupby for Country and their Currency

# %% [markdown]
# <h2 style='text-align:center;font-size:50px;background-color:white;border:50px;color:black'> Visualization <h2>

# %%
df.columns
# Out:
# Index(['Restaurant Name', 'Country Code', 'City', 'Locality',
#        'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
(df['City'].value_counts()).plot(kind='pie',autopct='%1.1f%%', figsize=(30,15) )
plt.legend(title ="City",loc ="best",bbox_to_anchor =(1, 0.5, 0.5, 1))
plt.title("Percentage of different City used by Zomato Restaurants")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### New Delhi have maximum restaurant and Vineland Station have least number of restaurants

# %%
df.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %% [markdown]
# #### We see that country India is Has the maximum counts in all the dataset

# %% [markdown]
# # Lets list all the country now and do analysis

# %%
indiaRes=df[df['Country']=='India']
singaporeRes=df[df['Country']=='Singapore']
AusRes=df[df['Country']=='Australia']
BrazRes=df[df['Country']=='Brazil']
CanadaRes=df[df['Country']=='Canada']
UAERes=df[df['Country']=='UAE']
UKRes=df[df['Country']=='United Kingdom']
USRes=df[df['Country']=='United States']
SouthAfricaRes=df[df['Country']=='South Africa']
NewZelandRes=df[df['Country']=='New Zealand']
TurkeyRes=df[df['Country']=='Turkey']
IndonesiaRes=df[df['Country']=='Indonesia']
QatarRes=df[df['Country']=='Qatar']
SrilankaRes=df[df['Country']=='Sri Lanka']

# %%
##This is the list of country India
indiaRes.head()
# Out:
#                            Restaurant Name  Country Code  City     Locality  \
# 624                             Jahanpanah             1  Agra   Agra Cantt
# 625                    Rangrezz Restaurant             1  Agra   Agra Cantt
# 626                Time2Eat - Mama Chicken             1  Agra   Agra Cantt
# 627  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra  Civil Lines
# 628                         Pinch Of Spice             1  Agra  Civil Lines
#
#       Locality Verbose  Longitude   Latitude                        Cuisines  \
# 624   Agra Cantt, Agra  78.011544  27.161661           North Indian, Mughlai
# 625   Agra Cantt, Agra   0.000000   0.000000           North Indian, Mughlai
# 626   Agra Cantt, Agra  78.011608  27.160832                    North Indian
# 627  Civil Lines, Agra  77.998092  27.195928                      Rajasthani
# 628  Civil Lines, Agra  78.007553  27.201725  North Indian, Chinese, Mughlai
#
# ...

# %%
indiaRes.City.value_counts()
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Lucknow           21
# Bhubaneshwar      21
# Amritsar          21
# Pune              20
# Puducherry        20
# Patna             20
# Ludhiana          20
# Ranchi            20
# Surat             20
# Vadodara          20
# Nashik            20
# Nagpur            20
# Mysore            20
# Mumbai            20
# Varanasi          20
# Mangalore         20
# Agra              20
# Kochi             20
# Kolkata           20
# Dehradun          20
# Allahabad         20
# Aurangabad        20
# Bangalore         20
# Bhopal            20
# Chennai           20
# Coimbatore        20
# Goa               20
# Indore            20
# Jaipur            20
# Kanpur            20
# Vizag             20
# Chandigarh        18
# Hyderabad         18
# Secunderabad       2
# Panchkula          1
# Mohali             1
# ...

# %%
plt.figure(figsize=(10,10))
sns.countplot(indiaRes['City'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### New Delhi has the highest Count of Restaurant in India and the least is Mohali

# %% [markdown]
# ## Top restaurant in delhi based on the rating and vote count

# %%
DelhiTopRes=indiaRes[(indiaRes['City']=='New Delhi')&(indiaRes['Aggregate rating']>4.5)][['Aggregate rating','Restaurant Name','Votes']].sort_values(ascending=False,by='Votes')

# %%
DelhiTopRes
# Out:
#       Aggregate rating            Restaurant Name  Votes
# 3013               4.9         Naturals Ice Cream   2620
# 3601               4.9  Indian Accent - The Manor   1934
# 6659               4.6   The California Boulevard   1691
# 4639               4.6                  Big Chill   1569
# 6997               4.7        Echoes Satyaniketan   1563
# 7849               4.6            Cafeteria & Co.   1136
# 3310               4.6              Spezia Bistro   1071
# 6657               4.7         Naturals Ice Cream    474
# 4298               4.9             Masala Library    408
# 3732               4.6                     Tashan    304
# 7067               4.7                   Pa Pa Ya    268
# 3014               4.7   Zabardast Indian Kitchen    242
# 6655               4.6         Band Baaja Baaraat    128
# 7180               4.6                Greenr Cafe    112
# 6656               4.8               Kopper Kadai     83
# ...

# %%
plt.figure(figsize=(10,10))
sns.countplot(DelhiTopRes['Restaurant Name'],palette='bone')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### As per the Aggregate rating and Votes Naturals Ice creams has the highest rating and Votes and rest all are constant from Delhii

# %% [markdown]
# ## Top 5 restaurants with online delivery in New Delhi

# %%
DelhiTopResOnline=indiaRes[(indiaRes['City']=='New Delhi')&(indiaRes['Aggregate rating']>4.5) &(indiaRes['Has Online delivery']=='Yes')][['Aggregate rating','Restaurant Name','Votes','Has Online delivery']].sort_values(ascending=False,by='Votes')

# %%
DelhiTopResOnline
# Out:
#       Aggregate rating           Restaurant Name  Votes Has Online delivery
# 3013               4.9        Naturals Ice Cream   2620                 Yes
# 3310               4.6             Spezia Bistro   1071                 Yes
# 6657               4.7        Naturals Ice Cream    474                 Yes
# 3014               4.7  Zabardast Indian Kitchen    242                 Yes
# 7180               4.6               Greenr Cafe    112                 Yes
# 6426               4.6               Food Scouts     61                 Yes

# %% [markdown]
# #### These are the top 5 restaurants which offers online delivery

# %%
plt.figure(figsize=(10,10))
sns.factorplot('Restaurant Name',kind='count',data=DelhiTopResOnline,hue='Has Online delivery',palette="ocean")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### plotting of restaurants and has online delivery

# %% [markdown]
# ### Lets see whether Votes and aggregate rating have any relationship or not

# %%
sns.lineplot('Votes','Aggregate rating',data=DelhiTopRes)
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Aggregate rating'>

# %% [markdown]
# #### We can see that there is no linear Relationship between Votes and Aggregate rating .. This may be because votes may be given in against of any restuarants but will be counted Votes given but in case of aggregate rating it will be given as per the Service

# %%
df['Price range'].value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Price range'],palette='Paired')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Price range 1 is max in number

# %%
def generate_pie(i):
    plt.figure(figsize=(10,5),facecolor='orange')
    plt.pie(i.value_counts(), labels=i.value_counts().index, autopct='%1.2f%%',shadow=True,)
    plt.legend(prop={'size':14})
    plt.axis('equal')
    plt.tight_layout()
    return plt.show()

# %%
cols1 = ['Has Table booking', 'Has Online delivery', 'Is delivering now','Price range', 'Rating color','Rating text']

# %%
plotnumber=1
for j in df[cols1]:
    print(f"Pie plot for the column:", j)
    generate_pie(df[j])
# Out:
# Pie plot for the column: Has Table booking
# Pie plot for the column: Has Online delivery
# Pie plot for the column: Is delivering now
# Pie plot for the column: Price range
# Pie plot for the column: Rating color
# Pie plot for the column: Rating text

# %% [markdown]
# ### Observation :-
# - Online Delivery is very less in India.
# - Very less company are delivery now.
# - Maximum price range is 1.
# - Rating color Orange in maximum.
# - Rating Text is maximum Average.

# %% [markdown]
# ## Top Cuisines in each Region

# %%
IndianCuisines=df[df['Country']=='India']['Cuisines'].value_counts().head()
IndianCuisines
# Out:
# North Indian             936
# North Indian, Chinese    511
# Fast Food                348
# Chinese                  340
# North Indian, Mughlai    334
# Name: Cuisines, dtype: int64

# %%
plt.figure(figsize=(10,10))
indiaRes['Cuisines'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Cuisines'>

# %% [markdown]
# ### North Indian dishes are most in counts and the least is street food

# %%
# Checking how the data has been distriubted in each column

plt.figure(figsize=(25,35),facecolor='white')
plotnumber=1
for column in numerical_col:
    if plotnumber<=23:
        ax=plt.subplot(6,4,plotnumber)
        sns.distplot(df[column],color="orange",hist=False,kde_kws={"shade": True})
        plt.xlabel(column,fontsize=18)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# #### We can see that Skewness is present in the dataset

# %%
rating_price= df.groupby('Price range').mean()['Aggregate rating'].sort_values(ascending=True)
print(rating_price)
(rating_price).plot(kind='line', xlabel='Price range', ylabel='Average of ratings', title='Average rating v/s Price range')
# Out:
# Price range
# 1    1.999887
# 2    2.941054
# 3    3.683381
# 4    3.817918
# Name: Aggregate rating, dtype: float64
# <AxesSubplot:title={'center':'Average rating v/s Price range'}, xlabel='Price range', ylabel='Average of ratings'>

# %% [markdown]
# ### We can see that it has a linear relationship ,when we compare Aggregate rating and price range

# %%
plt.figure(figsize=(10,10))
sns.boxplot(indiaRes["Rating text"],indiaRes["Average Cost for two"],palette='spring')
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='Average Cost for two'>

# %% [markdown]
# #### The plot shows rating does influence the cost of service at a restaurant

# %%
print(df['Rating text'].unique())
print(df['Rating text'].nunique())
print(df['Rating text'].value_counts())
# Out:
# ['Excellent' 'Very Good' 'Good' 'Average' 'Not rated' 'Poor']
# 6
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64

# %%
(df['Rating text'].value_counts()[:6]).plot(kind='bar', color=['orange','green','pink','blue','black','red'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### yes we can see that the maximum rating text is Average and the least is poor

# %% [markdown]
# ## Now Lets see what are Top10 rating Restaraunts

# %%
r1= (df.loc[df['Aggregate rating'] > 4.5, 'Restaurant Name'])
print(r1)
print(len(r1))
print(r1.value_counts())
((r1.value_counts()).head(10)).plot(kind='barh', color='black', figsize=(10,10))
plt.ylabel("Restaurants")
plt.title("Top 10 High Rated restaurant ")
# Out:
# 0                               Le Petit Souffle
# 3                                           Ooma
# 4                                    Sambo Kojin
# 8       Spiral - Sofitel Philippine Plaza Manila
# 9                                       Locavore
#                           ...
# 9536                             Pizza ��l Forno
# 9537                         J'adore Chocolatier
# 9538                                   Starbucks
# 9540                            Draft Gastro Pub
# 9544                       Karak�_y G�_ll�_o��lu
# Name: Restaurant Name, Length: 206, dtype: object
# 206
# Barbeque Nation                               7
# AB's - Absolute Barbecues                     4
# Talaga Sampireun                              3
# Chili's                                       3
# Mocha                                         2
#                                              ..
# Mazzaro's Italian Market                      1
# Mr. Dunderbak's Biergarten and Marketplatz    1
# ...

# %% [markdown]
# #### We can see that the Barbeque Nation is the Max rated restaraunts in Top 10

# %%
df.groupby('Restaurant Name').mean()['Votes'].sort_values(ascending=False)
# Out:
# Restaurant Name
# Toit                               10934.0
# Hauz Khas Social                    7931.0
# Peter Cat                           7574.0
# Big Brewsky                         5705.0
# The Black Pearl                     5385.0
#                                     ...
# New Bhappe Di Hatti                    0.0
# New Aggarwal Sweets & Fast Food        0.0
# Nehra's Food Point                     0.0
# Negi Restaurant                        0.0
# Laxmi Food Corner                      0.0
# Name: Votes, Length: 7446, dtype: float64

# %%
df.groupby('Restaurant Name').mean()['Votes'].sort_values(ascending=False)[:10].plot(kind='bar', color='black', figsize=(10,8), title="Outlets Having Maximum Votes", xlabel='Top 10 Outlets', ylabel='Average votes')
# Out:
# <AxesSubplot:title={'center':'Outlets Having Maximum Votes'}, xlabel='Top 10 Outlets', ylabel='Average votes'>

# %% [markdown]
# #### From top 10 restaurant according to votes Toits has the maximum votes

# %%
df.plot(kind='box',subplots=True,layout=(10,5),figsize=(20,20),color='pink')
# Out:
# Country Code               AxesSubplot(0.125,0.816017;0.133621x0.0639831)
# Longitude               AxesSubplot(0.285345,0.816017;0.133621x0.0639831)
# Latitude                 AxesSubplot(0.44569,0.816017;0.133621x0.0639831)
# Average Cost for two    AxesSubplot(0.606034,0.816017;0.133621x0.0639831)
# Price range             AxesSubplot(0.766379,0.816017;0.133621x0.0639831)
# Aggregate rating           AxesSubplot(0.125,0.739237;0.133621x0.0639831)
# Votes                   AxesSubplot(0.285345,0.739237;0.133621x0.0639831)
# dtype: object

# %% [markdown]
# #### All the Numerical columns have Outlier present....Country Code,Longitude,Latitude,Average Cost for two,Price range,Aggregate rating,Votes have Outlier present

# %% [markdown]
# <h2 style='text-align:center;font-size:50px;background-color:white;border:50px;color:black'> CORRELATION <h2>

# %%
df.nunique()
# Out:
# Restaurant Name         7446
# Country Code              15
# City                     141
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1826
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %% [markdown]
# #### Switch to order menu it has only one counts as 'No',and it is not contributing more to target

# %%
df.drop("Switch to order menu",axis=1,inplace=True)

# %% [markdown]
# #### We are also dropping Restaurant Name as it has all have as Unique and it is just a name of the resturent

# %%
df.drop("Restaurant Name",axis=1,inplace=True)

# %% [markdown]
# # Lets Convert all catagorical columns to Numerical by Encoding Tech

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#       Country Code  City  Locality  Locality Verbose   Longitude   Latitude  \
# 0              162    73       171               172  121.027535  14.565443
# 1              162    73       593               601  121.014101  14.553708
# 2              162    75       308               314  121.056831  14.581404
# 3              162    75       862               875  121.056475  14.585318
# 4              162    75       862               875  121.057508  14.584450
# ...            ...   ...       ...               ...         ...        ...
# 9546           208   140       517               523   28.977392  41.022793
# 9547           208   140       552               558   29.041297  41.009847
# 9548           208   140       554               561   29.034640  41.055817
# 9549           208   140       554               561   29.036019  41.057979
# 9550           208   140       670               681   29.026016  40.984776
#
# ...

# %%
df.corr()
# Out:
#                       Country Code      City  Locality  Locality Verbose  \
# Country Code              1.000000 -0.181728 -0.120076         -0.117543
# City                     -0.181728  1.000000  0.096443          0.093141
# Locality                 -0.120076  0.096443  1.000000          0.999465
# Locality Verbose         -0.117543  0.093141  0.999465          1.000000
# Longitude                -0.698299  0.117391  0.086446          0.084340
# Latitude                  0.019792 -0.004301 -0.020428         -0.020909
# Cuisines                 -0.132983  0.026632  0.007019          0.005986
# Average Cost for two      0.043225 -0.028838 -0.012136         -0.011852
# Currency                 -0.033466 -0.071996  0.023718          0.022960
# Has Table booking        -0.061682 -0.003762 -0.065594         -0.065132
# Has Online delivery      -0.154605  0.012723 -0.030993         -0.031766
# Is delivering now        -0.018291 -0.014039 -0.007299         -0.007353
# ...

# %% [markdown]
# ### Here we can see correlation of all the columns

# %%
# Visualizing the correlation matrix by plotting heat map.
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.2g', annot = True, linecolor="black",annot_kws={'size':10},cmap="ocean")
plt.yticks(rotation=0);

# %% [markdown]
# #### This heatmap shows the correlation matrix by visualizing the data. we can observe the relation between feature to feature and feature to label. This heat mapcontains both positive and negative correlation.

# %%
df.corr()['Average Cost for two'].sort_values()
# Out:
# Latitude               -0.111088
# Rating color           -0.049970
# City                   -0.028838
# Has Online delivery    -0.018974
# Locality               -0.012136
# Locality Verbose       -0.011852
# Country                -0.004034
# Is delivering now      -0.001862
# Cuisines                0.005819
# Has Table booking       0.007758
# Rating text             0.031439
# Country Code            0.043225
# Currency                0.045615
# Longitude               0.045891
# Aggregate rating        0.051792
# Votes                   0.067783
# Price range             0.075083
# Average Cost for two    1.000000
# Name: Average Cost for two, dtype: float64

# %%
#checking the columns which are positively and negatively correlated

plt.figure(figsize=(30,15))
df.corr()['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind='bar',color='black')
plt.xlabel('Features',fontsize=40)
plt.ylabel('columns with target names',fontsize=20)
plt.title('CORRELATION',fontsize=40)
plt.show()

# %% [markdown]
# #### Here we can see the least correlated columns are-> Is delivering now and Country and the max postive and Negative correlated columns as Price Range and Latitude.Here we can see the least correlated columns are-> Is delivering now and Country and the max postive and Negative correlated columns as Price Range and Latitude.

# %% [markdown]
# ## Lets Drop Both the Columns bcz it will not contribute to Target variable

# %%
df.drop("Is delivering now",axis=1,inplace=True)
df.drop("Country",axis=1,inplace=True)

# %% [markdown]
# <h2 style='text-align:center;font-size:60px;background-color:white;border:40px;color:black'> DESCRIPTIVE STATISTICS <h2>

# %%
df.describe()
# Out:
#        Country Code         City     Locality  Locality Verbose    Longitude  \
# count   9551.000000  9551.000000  9551.000000       9551.000000  9551.000000
# mean      18.365616    78.301434   658.128678        677.305204    64.126574
# std       56.750546    23.198915   315.866877        331.727817    41.467058
# min        1.000000     0.000000     0.000000          0.000000  -157.948486
# 25%        1.000000    76.000000   381.000000        387.000000    77.081343
# 50%        1.000000    88.000000   696.000000        707.000000    77.191964
# 75%        1.000000    88.000000   921.000000        953.000000    77.282006
# max      216.000000   140.000000  1207.000000       1264.000000   174.832089
#
#           Latitude     Cuisines  Average Cost for two     Currency  \
# count  9551.000000  9551.000000           9551.000000  9551.000000
# mean     25.854381   989.883363           1199.210763     3.977699
# std      11.007935   514.573865          16121.183073     0.914242
# ...

# %% [markdown]
# #### Observation:
# - In many columns mean greater than median(50%) which means column is right skewed
# - In many columns there is a lot of difference between 75% and max which means there is presence of outliers.
# - Count of all column are equal which means there is no nan value present in dataset.

# %%
plt.figure(figsize=(35,17))
sns.heatmap(df.describe(),annot=True,linewidths=0.5,linecolor="white",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Outcome of describe() of dataset :-
# - from the above plotting we are determining mean,standard deviation,minimum and maximum value of each column
#
# - Total number rows and column in dataset:-
#
# - - Rows :- 9551
#
# - - columns :- 16

# %% [markdown]
#  <h2 style='text-align:center;font-size:50px;background-color:white;border:30px;color:black'> Now Lets Remove Outliers Now <h2>

# %% [markdown]
# # ZScore Method

# %%
df.columns
# Out:
# Index(['Country Code', 'City', 'Locality', 'Locality Verbose', 'Longitude',
#        'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Price range',
#        'Aggregate rating', 'Rating color', 'Rating text', 'Votes'],
#       dtype='object')

# %%
# Features containing outliers
features = df[['Country Code','Longitude','Latitude','Average Cost for two','Price range','Aggregate rating','Votes']]

# Using zscore to remove outliers
from scipy.stats import zscore

z=np.abs(zscore(features))

z
# Out:
#       Country Code  Longitude  Latitude  Average Cost for two  Price range  \
# 0         2.531111   1.372269  1.025581              0.006154     1.319803
# 1         2.531111   1.371945  1.026647              0.000049     1.319803
# 2         2.531111   1.372975  1.024131              0.173743     2.424090
# 3         2.531111   1.372966  1.023775              0.018659     2.424090
# 4         2.531111   1.372991  1.023854              0.018659     2.424090
# ...            ...        ...       ...                   ...          ...
# 9546      3.341718   0.847685  1.378025              0.069428     1.319803
# 9547      3.341718   0.846144  1.376849              0.067878     1.319803
# 9548      3.341718   0.846305  1.381025              0.063845     2.424090
# 9549      3.341718   0.846272  1.381221              0.066947     2.424090
# 9550      3.341718   0.846513  1.374571              0.070979     0.215516
#
#       Aggregate rating     Votes
# 0             1.407131  0.365202
# ...

# %%
# Creating new dataframe
df_new = df[(z<3).all(axis=1)] 
df_new
# Out:
#       Country Code  City  Locality  Locality Verbose   Longitude   Latitude  \
# 0              162    73       171               172  121.027535  14.565443
# 1              162    73       593               601  121.014101  14.553708
# 2              162    75       308               314  121.056831  14.581404
# 3              162    75       862               875  121.056475  14.585318
# 4              162    75       862               875  121.057508  14.584450
# ...            ...   ...       ...               ...         ...        ...
# 9432           166    38      1063              1116   51.526653  25.323261
# 9433           166    38      1086              1139   51.530127  25.350325
# 9434           166    38      1092              1145   51.512909  25.276180
# 9435           166    38      1115              1170   51.544576  25.273020
# 9436           166    38      1115              1170   51.546714  25.283011
#
# ...

# %%
df_new.shape
# Out:
# (8565, 16)

# %%
df.shape
# Out:
# (9551, 16)

# %%
# Percentage of data loss

DataLoss=((9551-8565)/9551)*100
DataLoss
# Out:
# 10.323526332321222

# %% [markdown]
# ### 10% data loss in zscore Method

# %% [markdown]
# # IQR Method

# %%
#1st quantile
Q1=df.quantile(0.25)

# 3rd quantile
Q3=df.quantile(0.75)

#IQR
IQR=Q3 - Q1
qq=df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
print("Old DataFrame data in Rows and Column:",df.shape)
print("\nNew DataFrame data in Rows and Column:",qq.shape)
print("\nTotal Dropped rows:",df.shape[0]-qq.shape[0])
# Out:
# Old DataFrame data in Rows and Column: (9551, 16)
#
# New DataFrame data in Rows and Column: (3552, 16)
#
# Total Dropped rows: 5999

# %%
#Percentage Data Loss using IQR
data_loss1 = (9551-3552)/9551*100
data_loss1
# Out:
# 62.81017694482253

# %% [markdown]
# ### 62% of ata loss in iqr method

# %% [markdown]
# ## I am going for ZScore Method

# %% [markdown]
# <h2 style='text-align:center;font-size:50px;background-color:white;border:50px;color:black'> Lets Check Skewness <h2>

# %%
df.skew()
# Out:
# Country Code             3.043965
# City                    -1.193777
# Locality                -0.253550
# Locality Verbose        -0.183059
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.306743
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# dtype: float64

# %% [raw]
# Numerical columns are:
#  ['Country Code', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %% [raw]
# As a general rule of thumb:
#
# ​------------------------------------------------------------------------------------------------
# If skewness is less than -1 or greater than 1, the distribution is highly skewed.
#
# If skewness is between -1 and -0.5 or between 0.5 and 1, the distribution is moderately skewed.
#
# If skewness is between -0.5 and 0.5, the distribution is approximately symmetric
#
# ---------------------------------------------------------------------------------------------------
# Acceptable range of Skewness: -0.5/+0,5
#
# ---------------------------------------------------------------------------------------------------
#
# Country Code,Longitude,Latitude ,Average Cost for two,Price range,Aggregate rating,Votes,   have Skewness and it is needed to be removed ,Rest all columns which are showing skewness are catagorical columns and in this we are not required to remove skewness but here even Senior Citizen is containing data which is of catagorical type

# %%
#Lets plot all using Histogram and see the skewness again
 
plt.rcParams['figure.figsize']=(30,20)
df.hist(bins=25,color='black',density=True,label='Value',histtype='bar')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### [Country Code,Longitude,Latitude ,Average Cost for two,Price range,Aggregate rating,Votes] have Skewness and it is needed to be removed ,Rest all columns which are showing skewness are catagorical columns and in this we are not required to remove skewness.

# %%
L1=['Country Code','Longitude','Latitude' ,'Average Cost for two','Price range','Aggregate rating','Votes']

# %%
# Lets remove the skewness from given columns by Power Transform Method

from sklearn.preprocessing import PowerTransformer
PT = PowerTransformer(method='yeo-johnson')

# %%
#Removing skewness using yeo-johnson
df_new[['Country Code','Longitude','Latitude' ,'Average Cost for two','Price range','Aggregate rating','Votes']] = PT.fit_transform(df_new[['Country Code','Longitude','Latitude' ,'Average Cost for two','Price range','Aggregate rating','Votes']].values)

# %%
#After removing let's check how the data has been distributed in each column of skew_features.

plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df_new[L1]:
    if plotnumber<=9:
        ax = plt.subplot(2,7,plotnumber)
        sns.distplot(df_new[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %% [markdown]
# ### We can see that the skewness have been removed and the graph is normalized now

# %% [markdown]
# <h2 style='text-align:center;font-size:60px;background-color:white;border:30px;color:black'> Now Lets Split the dataset <h2>

# %%
df_new.head()
# Out:
#    Country Code  City  Locality  Locality Verbose  Longitude  Latitude  \
# 0     11.616899    73       171               172   7.096817 -2.870154
# 1     11.616899    73       593               601   7.094048 -2.870996
# 2     11.616899    75       308               314   7.102859 -2.869007
# 3     11.616899    75       862               875   7.102785 -2.868725
# 4     11.616899    75       862               875   7.102998 -2.868788
#
#    Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0       920              1.170136         0                  1
# 1      1111              1.291498         0                  1
# 2      1672              3.044151         0                  1
# 3      1126              1.605942         0                  0
# 4      1122              1.605942         0                  1
#
#    Has Online delivery  Price range  Aggregate rating  Rating color  \
# 0                    0     1.385129          1.972392             0
# ...

# %%
x=df_new.loc [:,df_new.columns != 'Average Cost for two']
# Independent Variable

# %%
y=df_new.loc[:,'Average Cost for two']
#Dependent Variable

# %%
x.shape,y.shape
# Out:
# ((8565, 15), (8565,))

# %% [markdown]
# <h2 style='text-align:center;font-size:50px;background-color:white;border:50px;color:black'> Now Lets Scale The Dataset <h2>

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

x= pd.DataFrame(sc.fit_transform(x), columns=x.columns)
x
# Out:
#       Country Code      City  Locality  Locality Verbose  Longitude  Latitude  \
# 0        11.616901 -0.350524 -1.639342         -1.617142   7.096817 -2.870154
# 1        11.616901 -0.350524 -0.261938         -0.285302   7.094048 -2.870996
# 2        11.616901 -0.246545 -1.192175         -1.176300   7.102859 -2.869007
# 3        11.616901 -0.246545  0.616075          0.565336   7.102785 -2.868725
# 4        11.616901 -0.246545  0.616075          0.565336   7.102998 -2.868788
# ...            ...       ...       ...               ...        ...       ...
# 8560     11.616901 -2.170157  1.272136          1.313526  -2.075973 -0.937919
# 8561     11.616901 -2.170157  1.347208          1.384930  -2.075747 -0.929022
# 8562     11.616901 -2.170157  1.366792          1.403557  -2.076865 -0.953334
# 8563     11.616901 -2.170157  1.441864          1.481170  -2.074809 -0.954365
# 8564     11.616901 -2.170157  1.441864          1.481170  -2.074670 -0.951102
#
# ...

# %% [markdown]
# ### independent variable have been scaled

# %% [markdown]
# # WE CHECK MULTICOLLINEARITY BY VARIANCE INFLATION FACTOR (VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif_cal():
    vif=pd.DataFrame()
    vif["VIF FACTOR"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif["FEATURES"]=x.columns
    print (vif)

# %%
vif_cal()
# Out:
#     VIF FACTOR             FEATURES
# 0     1.461026         Country Code
# 1     1.078664                 City
# 2   886.414838             Locality
# 3   886.135223     Locality Verbose
# 4     3.080093            Longitude
# 5     2.787892             Latitude
# 6     1.025043             Cuisines
# 7     1.503753             Currency
# 8     1.395456    Has Table booking
# 9     1.230983  Has Online delivery
# 10    1.758696          Price range
# 11    4.708945     Aggregate rating
# 12    1.239534         Rating color
# 13    1.305338          Rating text
# 14    5.042861                Votes

# %%
# dropping column with highest vif
x.drop("Locality",axis=1,inplace=True)

# %%
def vif_cal():
    vif=pd.DataFrame()
    vif["VIF FACTOR"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif["FEATURES"]=x.columns
    print (vif)

# %%
vif_cal()
# Out:
#     VIF FACTOR             FEATURES
# 0     1.460309         Country Code
# 1     1.072068                 City
# 2     1.039195     Locality Verbose
# 3     3.078911            Longitude
# 4     2.787356             Latitude
# 5     1.024337             Cuisines
# 6     1.503571             Currency
# 7     1.395387    Has Table booking
# 8     1.229997  Has Online delivery
# 9     1.756796          Price range
# 10    4.708015     Aggregate rating
# 11    1.239424         Rating color
# 12    1.304927          Rating text
# 13    5.039398                Votes

# %% [markdown]
# ### Multicollinearity have been removed now.. as vif value of each column is less than 10

# %% [markdown]
# # Model Training And Testing

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print (f"At random state {i},the training accuracy is :- {r2_score(y_train,pred_train)}")
    print (f"At random state {i},the testing accuracy is :- {r2_score(y_test,pred_test)}")
    print ("\n\n")
# Out:
# At random state 0,the training accuracy is :- 0.7360751122023199
# At random state 0,the testing accuracy is :- 0.7448875254445866
#
#
#
# At random state 1,the training accuracy is :- 0.735315618659731
# At random state 1,the testing accuracy is :- 0.7491652451434669
#
#
#
# At random state 2,the training accuracy is :- 0.7394136212214001
# At random state 2,the testing accuracy is :- 0.7326480741467911
#
#
#
# At random state 3,the training accuracy is :- 0.7406144219116186
# At random state 3,the testing accuracy is :- 0.7275027582254112
#
#
#
# At random state 4,the training accuracy is :- 0.731568050474454
# At random state 4,the testing accuracy is :- 0.7635025186565583
#
#
#
# At random state 5,the training accuracy is :- 0.7338516697630516
# At random state 5,the testing accuracy is :- 0.7533456818101055
#
#
#
# At random state 6,the training accuracy is :- 0.7368341482265867
# At random state 6,the testing accuracy is :- 0.7424310297195039
#
#
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)

# %%
# train the model
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# predict the  data with x_test

pred_test=lr.predict(x_test)

# %%
print (r2_score(y_test,pred_test))
# Out:
# 0.7316214640404561

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=r2_score(y_test,pred_lr)

# %%
for i in range(4,10):
    lsscore=cross_val_score(lr,x,y,cv=i)
    lsc=lsscore.mean()
    print ("At cv:-",i)
    print ("Cross validation score is :-",lsc*100)
    print ("Accuracy_score is :-",lss*100)
    print ("\n")
# Out:
# At cv:- 4
# Cross validation score is :- -3.4640389511303575
# Accuracy_score is :- 73.16214640404561
#
#
# At cv:- 5
# Cross validation score is :- 43.91280585360975
# Accuracy_score is :- 73.16214640404561
#
#
# At cv:- 6
# Cross validation score is :- 44.982443225377786
# Accuracy_score is :- 73.16214640404561
#
#
# At cv:- 7
# Cross validation score is :- 46.18742105413052
# Accuracy_score is :- 73.16214640404561
#
#
# At cv:- 8
# Cross validation score is :- 44.43692329050787
# Accuracy_score is :- 73.16214640404561
#
#
# At cv:- 9
# Cross validation score is :- 45.64163840895057
# Accuracy_score is :- 73.16214640404561

# %%
# I will take CV as 7 bcz its close to accuracy score
lsscore_selected= cross_val_score(lr,x,y,cv=7).mean()
print ("The cv score is :- ",lsscore_selected,"\nThe accuracy_score is:",lss)
# Out:
# The cv score is :-  0.4618742105413052
# The accuracy_score is: 0.7316214640404561

# %%
from sklearn import metrics

# %% [raw]
# MAE : The mean absolute error (MAE) is a measure of errors between paired observations expressing the same phenomenon.
# MSE : The mean squared error tells you how close a regression line is to a set of points. It does this by taking the distances from the points to the regression line (these distances are the “errors”) and squaring them.

# %%
MAE= metrics.mean_absolute_error(y_test,pred_test)
MSE= metrics.mean_squared_error(y_test,pred_test)

# %%
print("mean absolute error:",MAE)
print("mean squared error:",MSE)
# Out:
# mean absolute error: 0.3782284508989164
# mean squared error: 0.2899307621283671

# %%
from math import sqrt
rmse = sqrt(MSE)
print("Root Mean Squared Error:",rmse)
# Out:
# Root Mean Squared Error: 0.5384521911259783

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.scatter (x=y_test,y=pred_test,color='black')

plt.plot(y_test,y_test,color='b')

plt.xlabel('Actual charges' ,fontsize=14)

plt.ylabel('Predicted charges', fontsize=14)
plt.title('Linear Regression' , fontsize=20)
plt. show()

# %% [markdown]
# ### We can see that Most of the points falls on the best fit line which is good

# %%
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %%
# Checking R2 score for Decision Tree Regressor
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)

# prediction
predDTR=DTR.predict(x_test)
dt=r2_score(y_test,predDTR)
print('R2_Score:',dt)

print('cv :-' ,cross_val_score(DTR,x,y,cv=5).mean())
print('MAE:',metrics.mean_absolute_error(y_test, predDTR))
print('MSE:',metrics.mean_squared_error(y_test, predDTR))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predDTR)))

# Visualizing the predicteed values
plt.figure(figsize=(10,10))
sns.regplot(y_test,predDTR,color="purple")
plt.show()
# Out:
# R2_Score: 0.6769498171707373
# cv :- -1.9909719748813142
# MAE: 0.3669429426192143
# MSE: 0.3489928334936419
# RMSE: 0.5907561540040374

# %%
kn=KNeighborsRegressor()
kn.fit(x_train,y_train)

predkn=kn.predict(x_test)
print('R2_Score:',r2_score(y_test,predkn))
print('MAE:',metrics.mean_absolute_error(y_test, predkn))
print('MSE:',metrics.mean_squared_error(y_test, predkn))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predkn)))
print('cv :-' ,cross_val_score(kn,x,y,cv=5).mean())

# Visualizing the predicteed values
plt.figure(figsize=(10,10))
sns.regplot(y_test,predkn,color="orange")
plt.show()
# Out:
# R2_Score: 0.7076879521923789
# MAE: 0.3827068473270631
# MSE: 0.31578626247869074
# RMSE: 0.5619486297507013
# cv :- 0.6408995207163206

# %% [markdown]
# # Ensemble Technique

# %%
RF=RandomForestRegressor()
RF.fit(x_train,y_train)

predRF=RF.predict(x_test)
print('R2_Score:',r2_score(y_test,predRF))
print('MAE:',metrics.mean_absolute_error(y_test, predRF))
print('MSE:',metrics.mean_squared_error(y_test, predRF))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predRF)))
print('cv :-' ,cross_val_score(RF,x,y,cv=5).mean())

# Visualizing the predicteed values
plt.figure(figsize=(10,10))
sns.regplot(y_test,predkn,color="pink")
plt.show()
# Out:
# R2_Score: 0.7982732246670573
# MAE: 0.2916632371117891
# MSE: 0.21792651004994834
# RMSE: 0.4668259954736329
# cv :- -0.32678884926830437

# %%
gb=GradientBoostingRegressor()
gb.fit(x_train,y_train)

# prediction
predgb=gb.predict(x_test)
print('R2_Score:',r2_score(y_test,predgb))
print('MAE:',metrics.mean_absolute_error(y_test, predgb))
print('MSE:',metrics.mean_squared_error(y_test, predgb))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predgb)))
print('cv :-' ,cross_val_score(gb,x,y,cv=5).mean())

# Visualizing the predicteed values
plt.figure(figsize=(10,10))
sns.regplot(y_test,predkn,color="green")
plt.show()
# Out:
# R2_Score: 0.8028415742683181
# MAE: 0.2984982382312204
# MSE: 0.21299129763876645
# RMSE: 0.46150980232143113
# cv :- -0.008955082117656898

# %%
# Checking R2 score for Extra Trees Regressor

XT=ExtraTreesRegressor()
XT.fit(x_train,y_train)

# prediction
predXT=XT.predict(x_test)
etr=r2_score(y_test,predXT)
print('R2_Score:',etr)

print('cv :-' ,cross_val_score(XT,x,y,cv=5).mean())


# Metric Evaluation
print('MAE:',metrics.mean_absolute_error(y_test, predXT))
print('MSE:',metrics.mean_squared_error(y_test, predXT))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predXT)))

# Visualizing the predicted values
plt.figure(figsize=(10,10))
sns.regplot(y_test,predXT,color="crimson")
plt.show()
# Out:
# R2_Score: 0.797135428443659
# cv :- 0.5958996344647436
# MAE: 0.30162712504610645
# MSE: 0.21915567737146016
# RMSE: 0.4681406598143983

# %% [markdown]
# # Hyper parameter tuning

# %%
gb.get_params()
# Out:
# {'alpha': 0.9,
#  'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'squared_error',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
#Gradient boosting regressor
parameters = {'criterion':['friedman_mse', 'squared_error'],
             'max_features':['auto', 'sqrt', 'log2'],
             'loss':['squared_error','absolute_error','huber','quantile'],
             'warm_start':[True,False]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
gg=GridSearchCV(GradientBoostingRegressor(),parameters,cv=5)

# %%
gg.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error'],
#                          'loss': ['squared_error', 'absolute_error', 'huber',
#                                   'quantile'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'warm_start': [True, False]})

# %%
gg.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'loss': 'squared_error',
#  'max_features': 'auto',
#  'warm_start': True}

# %%
gb = GradientBoostingRegressor(criterion='friedman_mse', warm_start=True, max_features='auto',loss='squared_error')
gb.fit(x_train, y_train)
pred = gb.predict(x_test)
print('R2_Score:',r2_score(y_test,pred)*100)
# Out:
# R2_Score: 80.24484848922067

# %% [markdown]
# # Saving The Model

# %%
#Saving the model using .pkl
import joblib
joblib.dump(gb,"ZomatoReg_study.pkl")
# Out:
# ['ZomatoReg_study.pkl']

# %%
#Loading the saved model
aa=joblib.load("ZomatoReg_study.pkl")

# %%
#Prediction
prediction = aa.predict(x_test)
prediction
# Out:
# array([-0.36092222,  0.28112485,  0.4420251 , ...,  0.50938132,
#         0.34723615,  0.43006139])

# %%
pd.DataFrame([aa.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                0         1         2         3         4         5     \
# Predicted -0.360922  0.281125  0.442025  1.262595  0.413952  0.382817
# Original  -0.036765  0.101782  0.550848  1.037998  0.227962  0.550848
#
#                6         7         8         9         10        11    \
# Predicted  0.363239  0.635585  0.343961 -0.356214  0.804539 -0.723620
# Original   0.731876  0.101782  0.101782 -0.036765  0.731876 -1.070567
#
#                12        13        14        15        16        17    \
# Predicted  0.335535  1.420439 -0.761513 -0.645530 -0.794940 -0.488046
# Original   0.343860  1.403758 -0.363292 -1.070567 -1.423576 -0.190489
#
#                18        19        20        21        22        23    \
# Predicted  2.434897  1.391681 -0.668456 -0.405788 -1.149880  2.499402
# Original   2.018213  1.605942 -0.791810 -0.190489 -0.560837  2.018213
#
#                24        25        26        27        28        29    \
# ...

# %% [markdown]
# ## My model is Performing well and Average cost of Two  prediction is completed

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Now Target Variable is  Price Range*

# %%
df_new.head()
# Out:
#    Country Code  City  Locality  Locality Verbose  Longitude  Latitude  \
# 0     11.616899    73       171               172   7.096817 -2.870154
# 1     11.616899    73       593               601   7.094048 -2.870996
# 2     11.616899    75       308               314   7.102859 -2.869007
# 3     11.616899    75       862               875   7.102785 -2.868725
# 4     11.616899    75       862               875   7.102998 -2.868788
#
#    Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0       920              1.170136         0                  1
# 1      1111              1.291498         0                  1
# 2      1672              3.044151         0                  1
# 3      1126              1.605942         0                  0
# 4      1122              1.605942         0                  1
#
#    Has Online delivery  Price range  Aggregate rating  Rating color  \
# 0                    0     1.385129          1.972392             0
# ...

# %% [markdown]
# # Now lets split the dataset

# %%
x=df_new.loc [:,df_new.columns != 'Price range']
# Independent Variable

# %%
y=df_new.loc[:,'Price range']
#Dependent Variable

# %%
x.shape,y.shape
# Out:
# ((8565, 15), (8565,))

# %% [markdown]
# <h2 style='text-align:center;font-size:50px;background-color:Black;border:50px;color:white'> Now Lets Scale The Dataset <h2>

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

x= pd.DataFrame(sc.fit_transform(x), columns=x.columns)
x
# Out:
#       Country Code      City  Locality  Locality Verbose  Longitude  Latitude  \
# 0        11.616901 -0.350524 -1.639342         -1.617142   7.096817 -2.870154
# 1        11.616901 -0.350524 -0.261938         -0.285302   7.094048 -2.870996
# 2        11.616901 -0.246545 -1.192175         -1.176300   7.102859 -2.869007
# 3        11.616901 -0.246545  0.616075          0.565336   7.102785 -2.868725
# 4        11.616901 -0.246545  0.616075          0.565336   7.102998 -2.868788
# ...            ...       ...       ...               ...        ...       ...
# 8560     11.616901 -2.170157  1.272136          1.313526  -2.075973 -0.937919
# 8561     11.616901 -2.170157  1.347208          1.384930  -2.075747 -0.929022
# 8562     11.616901 -2.170157  1.366792          1.403557  -2.076865 -0.953334
# 8563     11.616901 -2.170157  1.441864          1.481170  -2.074809 -0.954365
# 8564     11.616901 -2.170157  1.441864          1.481170  -2.074670 -0.951102
#
# ...

# %% [markdown]
# ### Indepedent Variable have been scaled

# %% [markdown]
# # Checking Multicollinearity By VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif_cal():
    vif=pd.DataFrame()
    vif["VIF FACTOR"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif["FEATURES"]=x.columns
    print (vif)

# %%
vif_cal()
# Out:
#     VIF FACTOR              FEATURES
# 0     1.475030          Country Code
# 1     1.074423                  City
# 2   885.949336              Locality
# 3   885.707783      Locality Verbose
# 4     3.072312             Longitude
# 5     2.750830              Latitude
# 6     1.023001              Cuisines
# 7     1.861870  Average Cost for two
# 8     1.504706              Currency
# 9     1.536213     Has Table booking
# 10    1.226130   Has Online delivery
# 11    4.708992      Aggregate rating
# 12    1.240844          Rating color
# 13    1.306233           Rating text
# 14    5.035706                 Votes

# %%
x.drop("Locality",axis=1,inplace=True)  ##Dropping column with higjhest vif

# %%
def vif_cal():
    vif=pd.DataFrame()
    vif["VIF FACTOR"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif["FEATURES"]=x.columns
    print (vif)

# %%
vif_cal()
# Out:
#     VIF FACTOR              FEATURES
# 0     1.473966          Country Code
# 1     1.067577                  City
# 2     1.039599      Locality Verbose
# 3     3.071334             Longitude
# 4     2.750505              Latitude
# 5     1.022378              Cuisines
# 6     1.860836  Average Cost for two
# 7     1.504413              Currency
# 8     1.536170     Has Table booking
# 9     1.225244   Has Online delivery
# 10    4.708033      Aggregate rating
# 11    1.240725          Rating color
# 12    1.305804           Rating text
# 13    5.031673                 Votes

# %% [markdown]
# ### Now no column have multicollinearity as vif value of every column is less than 10

# %% [markdown]
# # Model Training And Testing

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
# Checking R2 score for Decision Tree Regressor
lr=LinearRegression()
lr.fit(x_train,y_train)

# prediction
predlr=lr.predict(x_test)
LR=r2_score(y_test,predlr)
print('R2_Score:',dt)

print('cv :-' ,cross_val_score(lr,x,y,cv=5).mean())
print('MAE:',metrics.mean_absolute_error(y_test, predlr))
print('MSE:',metrics.mean_squared_error(y_test, predlr))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predlr)))

# Visualizing the predicteed values
plt.figure(figsize=(10,10))
sns.regplot(y_test,predDTR,color="purple")
plt.show()
# Out:
# R2_Score: 0.6769498171707373
# cv :- 0.4062032228621857
# MAE: 0.3782284508989164
# MSE: 0.2899307621283671
# RMSE: 0.5384521911259783

# %%
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %%
# Checking R2 score for Decision Tree Regressor
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)

# prediction
predDTR=DTR.predict(x_test)
dt=r2_score(y_test,predDTR)
print('R2_Score:',dt)

print('cv :-' ,cross_val_score(DTR,x,y,cv=5).mean())
print('MAE:',metrics.mean_absolute_error(y_test, predDTR))
print('MSE:',metrics.mean_squared_error(y_test, predDTR))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predDTR)))

# Visualizing the predicteed values
plt.figure(figsize=(10,10))
sns.regplot(y_test,predDTR,color="red")
plt.show()
# Out:
# R2_Score: 0.6769059987496302
# cv :- 0.8042331090668924
# MAE: 0.3670719907170915
# MSE: 0.3490401707673975
# RMSE: 0.5907962176312552

# %%
kn=KNeighborsRegressor()
kn.fit(x_train,y_train)

predkn=kn.predict(x_test)
print('R2_Score:',r2_score(y_test,predkn))
print('MAE:',metrics.mean_absolute_error(y_test, predkn))
print('MSE:',metrics.mean_squared_error(y_test, predkn))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predkn)))
print('cv :-' ,cross_val_score(kn,x,y,cv=5).mean())

# Visualizing the predicteed values
plt.figure(figsize=(10,10))
sns.regplot(y_test,predkn,color="blue")
plt.show()
# Out:
# R2_Score: 0.7076879521923789
# MAE: 0.3827068473270631
# MSE: 0.31578626247869074
# RMSE: 0.5619486297507013
# cv :- 0.8031004989926075

# %% [markdown]
# # Ensemble Technique

# %%
RF=RandomForestRegressor()
RF.fit(x_train,y_train)

predRF=RF.predict(x_test)
print('R2_Score:',r2_score(y_test,predRF))
print('MAE:',metrics.mean_absolute_error(y_test, predRF))
print('MSE:',metrics.mean_squared_error(y_test, predRF))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predRF)))
print('cv :-' ,cross_val_score(RF,x,y,cv=5).mean())

# Visualizing the predicteed values
plt.figure(figsize=(10,10))
sns.regplot(y_test,predkn,color="green")
plt.show()
# Out:
# R2_Score: 0.7989149763045644
# MAE: 0.2924940707962828
# MSE: 0.21723322233715
# RMSE: 0.4660828492201253
# cv :- 0.8898754956141461

# %%
gb=GradientBoostingRegressor()
gb.fit(x_train,y_train)

# prediction
predgb=gb.predict(x_test)
print('R2_Score:',r2_score(y_test,predgb))
print('MAE:',metrics.mean_absolute_error(y_test, predgb))
print('MSE:',metrics.mean_squared_error(y_test, predgb))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predgb)))
print('cv :-' ,cross_val_score(gb,x,y,cv=5).mean())

# Visualizing the predicteed values
plt.figure(figsize=(10,10))
sns.regplot(y_test,predkn,color="orange")
plt.show()
# Out:
# R2_Score: 0.8035984275977742
# MAE: 0.29849439048615833
# MSE: 0.2121736649549751
# RMSE: 0.46062312681298917
# cv :- 0.8714472042451709

# %%
# Checking R2 score for Extra Trees Regressor

XT=ExtraTreesRegressor()
XT.fit(x_train,y_train)

# prediction
predXT=XT.predict(x_test)
etr=r2_score(y_test,predXT)
print('R2_Score:',etr)

print('cv :-' ,cross_val_score(XT,x,y,cv=5).mean())


# Metric Evaluation
print('MAE:',metrics.mean_absolute_error(y_test, predXT))
print('MSE:',metrics.mean_squared_error(y_test, predXT))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predXT)))

# Visualizing the predicted values
plt.figure(figsize=(10,10))
sns.regplot(y_test,predXT,color="pink")
plt.show()
# Out:
# R2_Score: 0.7979486209395359
# cv :- 0.9701355902310016
# MAE: 0.30109661313375363
# MSE: 0.2182771811860491
# RMSE: 0.4672014353424539

# %% [markdown]
# # Hyper parameter tuning

# %%
gb.get_params()
# Out:
# {'alpha': 0.9,
#  'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'squared_error',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
#Gradient boosting regressor
parameters = {'criterion':['friedman_mse', 'squared_error'],
             'max_features':['auto', 'sqrt', 'log2'],
             'loss':['squared_error','absolute_error','huber','quantile'],
             'warm_start':[True,False]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
gg=GridSearchCV(GradientBoostingRegressor(),parameters,cv=5)

# %%
gg.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error'],
#                          'loss': ['squared_error', 'absolute_error', 'huber',
#                                   'quantile'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'warm_start': [True, False]})

# %%
gg.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'loss': 'squared_error',
#  'max_features': 'auto',
#  'warm_start': False}

# %%
gb = GradientBoostingRegressor(criterion='friedman_mse', warm_start=False, max_features='auto',loss='squared_error')
gb.fit(x_train, y_train)
pred = gb.predict(x_test)
print('R2_Score:',r2_score(y_test,pred)*100)
# Out:
# R2_Score: 80.34866699334907

# %% [markdown]
# # Saving The Model

# %%
#Saving the model using .pkl
import joblib
joblib.dump(gb,"Zomato2_study.pkl")
# Out:
# ['Zomato2_study.pkl']

# %%
#Loading the saved model
aa=joblib.load("Zomato2_study.pkl")

# %%
#Prediction
prediction = aa.predict(x_test)
prediction
# Out:
# array([-0.36092222,  0.28112485,  0.4420251 , ...,  0.50938132,
#         0.34723615,  0.43006139])

# %%
pd.DataFrame([aa.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                0         1         2         3         4         5     \
# Predicted -0.360922  0.281125  0.442025  1.262595  0.413952  0.382817
# Original  -0.036765  0.101782  0.550848  1.037998  0.227962  0.550848
#
#                6         7         8         9         10        11    \
# Predicted  0.363239  0.635585  0.343961 -0.356214  0.804539 -0.723620
# Original   0.731876  0.101782  0.101782 -0.036765  0.731876 -1.070567
#
#                12        13        14        15        16        17    \
# Predicted  0.335535  1.420439 -0.761513 -0.645530 -0.794940 -0.488046
# Original   0.343860  1.403758 -0.363292 -1.070567 -1.423576 -0.190489
#
#                18        19        20        21        22        23    \
# Predicted  2.434897  1.391681 -0.668456 -0.405788 -1.149880  2.499402
# Original   2.018213  1.605942 -0.791810 -0.190489 -0.560837  2.018213
#
#                24        25        26        27        28        29    \
# ...

# %% [markdown]
# # My model is Performing well and this project is completed

# %% [markdown]
# # ---------------------------------

# %% [markdown]
# # -------------------------------------------

# %% [markdown]
# # -------------------------------------------------------------
